# %%
 import wandb
 import pandas as pd

 run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
 local_path = wandb.use_artifact("sample.csv:latest").file()
 df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: nguyenhuy39. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/mnt/d/Udacity/MLOps/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20240525_143329-9bcgdsmy</code>
# Syncing run <strong><a href='https://wandb.ai/nguyenhuy39/nyc_airbnb/runs/9bcgdsmy' target="_blank">northern-sky-6</a></strong> to <a href='https://wandb.ai/nguyenhuy39/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nguyenhuy39/nyc_airbnb' target="_blank">https://wandb.ai/nguyenhuy39/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/nguyenhuy39/nyc_airbnb/runs/9bcgdsmy' target="_blank">https://wandb.ai/nguyenhuy39/nyc_airbnb/runs/9bcgdsmy</a>

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.1.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (3.8.2)
# Collecting pydantic>=2 (from ydata-profiling->pandas-profiling)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2,>=1.16.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.32.2)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling->pandas-profiling)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.5 MB/s eta 0:00:00
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling->pandas-profiling)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.11.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading statsmodels-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-4.2.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.1 (from ydata-profiling->pandas-profiling)
#   Downloading wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling->pandas-profiling)
#   Downloading numba-0.59.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->pandas-profiling)
#   Downloading pywavelets-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (2.9.0)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling)
#   Downloading llvmlite-0.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.4.2)
# Collecting annotated-types>=0.4.0 (from pydantic>=2->ydata-profiling->pandas-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.2 (from pydantic>=2->ydata-profiling->pandas-profiling)
#   Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2024.2.2)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: attrs>=19.3.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling) (23.2.0)
# Collecting networkx>=2.4 (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: six in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 4.4 MB/s eta 0:00:0000:0100:01
# Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl (359 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 15.9 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 12.6 MB/s eta 0:00:00
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading multimethod-1.11.2-py3-none-any.whl (10 kB)
# Downloading numba-0.59.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 17.3 MB/s eta 0:00:0000:0100:01
# Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 16.5 MB/s eta 0:00:0000:01
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 14.5 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.4 MB/s eta 0:00:0000:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 11.5 MB/s eta 0:00:00
# Downloading statsmodels-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 23.8 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.6 MB/s eta 0:00:00
# Downloading typeguard-4.2.1-py3-none-any.whl (34 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 5.4 MB/s eta 0:00:00
# Downloading wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.1/511.1 kB 21.5 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading llvmlite-0.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 24.2 MB/s eta 0:00:0000:0100:01
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.6 MB/s eta 0:00:00a 0:00:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 13.1 MB/s eta 0:00:00
# Downloading pywavelets-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 28.0 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=b9b47fbfdb446f20c8f9f123db99ac907a2e416d45da51cb5c1444b5bbbb4112
#   Stored in directory: /home/huy/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tqdm, PyWavelets, pydantic-core, patsy, networkx, multimethod, llvmlite, dacite, annotated-types, pydantic, numba, imagehash, wordcloud, visions, statsmodels, seaborn, phik, ydata-profiling, pandas-profiling
# Successfully installed PyWavelets-1.6.0 annotated-types-0.7.0 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 llvmlite-0.42.0 multimethod-1.11.2 networkx-3.3 numba-0.59.1 pandas-profiling-3.6.6 patsy-0.5.6 phik-0.12.4 pydantic-2.7.1 pydantic-core-2.18.2 seaborn-0.13.2 statsmodels-0.14.2 tqdm-4.66.4 typeguard-4.2.1 visions-0.7.6 wordcloud-1.9.3 ydata-profiling-4.8.3

# %%
# !pip install pydantic-settings
# Out:
# Collecting pydantic-settings
#   Downloading pydantic_settings-2.2.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: pydantic>=2.3.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic-settings) (2.7.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2.3.0->pydantic-settings) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2.3.0->pydantic-settings) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2.3.0->pydantic-settings) (4.11.0)
# Downloading pydantic_settings-2.2.1-py3-none-any.whl (13 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, pydantic-settings
# Successfully installed pydantic-settings-2.2.1 python-dotenv-1.0.1

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (4.8.3)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (2.1.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (3.8.2)
# Requirement already satisfied: pydantic>=2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (2.7.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (2.32.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (4.2.1)
# Requirement already satisfied: imagehash==4.3.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ydata-profiling) (0.59.1)
# Requirement already satisfied: PyWavelets in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.9.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: six in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipywidgets) (8.24.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: pexpect>4.3 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 1.7 MB/s eta 0:00:00a 0:00:01m
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 18.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10

# %%
#import pandas_profiling
from ydata_profiling import ProfileReport

profile = ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|                                                                          | 0/5 [00:00<?, ?it/s]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# Summarize dataset:   0%|                                       | 0/21 [00:00<?, ?it/s, Describe variable:minimum_nights]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# Summarize dataset:   5%|█▍                             | 1/21 [00:00<00:05,  3.80it/s, Describe variable:minimum_nights]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# Summarize dataset:   5%|█▎                          | 1/21 [00:00<00:05,  3.80it/s, Describe variable:number_of_reviews]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# Summarize dataset:  10%|████                                       | 2/21 [00:00<00:04,  3.80it/s, Describe variable:id]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# Summarize dataset:  14%|█████▋                                  | 3/21 [00:00<00:04,  3.80it/s, Describe variable:price]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# Summarize dataset:  19%|███████▌                                | 4/21 [00:00<00:01, 12.53it/s, Describe variable:price]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# Summarize dataset:  19%|███████▏                              | 4/21 [00:00<00:01, 12.53it/s, Describe variable:host_id]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# Summarize dataset:  78%|████████████████████████████▏       | 18/23 [00:00<00:00, 23.90it/s, Calculate auto correlation]/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'Function <code object pandas_auto_compute at 0x7fe408687940, file "/home/huy/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/pandas/correlations_pandas.py", line 164>')
#   warnings.warn(
# Summarize dataset: 100%|███████████████████████████████████████████████████| 126/126 [00:12<00:00,  9.88it/s, Completed]
# Generate report structure: 100%|██████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.34s/it]
# Render widgets:   0%|                                                                             | 0/1 [00:00<?, ?it/s]
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
# 5   4402805         LRG 2br BKLYN APT CLOSE TO TRAINS AND PARK   22807362
# 6  30070126  ✩Prime Renovated 1/1 Apartment in Upper East S...    4968673
# 7  34231172      Fully renovated brick house floor in Brooklyn   59642348
# 8   5856760         Renovated 1BR in exciting, convenient area   29408349
# 9   7929441                 Beautiful Loft w/ Waterfront View!    1453898
#
#   host_name neighbourhood_group              neighbourhood  latitude  \
# 0      Iris              Queens                  Sunnyside  40.74271
# 1    Johlex           Manhattan             Hell's Kitchen  40.76682
# 2      John           Manhattan               West Village  40.73631
# 3     Regan              Queens                    Astoria  40.76424
# 4     Megan            Brooklyn                   Bushwick  40.69839
# 5     Jenny            Brooklyn  Prospect-Lefferts Gardens  40.66025
# 6      Sean           Manhattan            Upper East Side  40.76831
# 7     Kevin            Brooklyn                Sunset Park  40.64550
# 8      Chad           Manhattan                  Chinatown  40.71490
# 9   Anthony            Brooklyn               Williamsburg  40.71268
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.92493     Private room     74               2                  6
# 1  -73.98878  Entire home/apt    170               3                  0
# 2  -74.00611  Entire home/apt    245               3                 51
# 3  -73.92351  Entire home/apt    125               3                  1
# 4  -73.92044     Private room     65               2                  8
# 5  -73.96270  Entire home/apt    120               3                  3
# 6  -73.95929  Entire home/apt    200               5                  2
# 7  -74.01262  Entire home/apt     95               1                  9
# 8  -73.99976  Entire home/apt    179               5                  7
# 9  -73.96676     Private room    105               2                232
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2019-05-26               0.13                               1
# 1         NaN                NaN                               1
# 2  2018-09-19               1.12                               1
# 3  2019-05-24               0.65                               1
# 4  2019-06-23               0.52                               2
# 5  2018-08-28               0.05                               1
# 6  2019-05-26               0.68                               1
# 7  2019-07-08               9.00                               1
# 8  2017-04-18               0.14                               1
# 9  2019-06-19               5.00                               3
#
#    availability_365
# 0                 5
# 1               188
# 2                 0
# 3                13
# 4                 8
# 5                16
# 6                71
# 7               106
# 8                 0
# 9                64
#              id                                               name    host_id  \
# 19990   5192459                   Quiet Room in 4BR UWS Brownstone   10677483
# 19991   1327940                 Huge Gorgeous Park View Apartment!    3290436
# 19992  23612681   Shared Room 1 Stop from Manhattan on the F Train   55724558
# 19993  34485745           Midtown Manhattan Stunner - Private room  261632622
# 19994  25616250  Stylish, spacious, private 1BR apt in Ditmas Park  125396920
# 19995   7094539                  Tranquil haven in bubbly Brooklyn    2052211
# 19996   4424261                    Large 1 BR with backyard on UWS    3447311
# 19997   4545882                Amazing studio/Loft with a backyard   23569951
# 19998  26518547          U2 comfortable double bed sleeps 2 guests     295128
# 19999  33631782               Private Bedroom in Williamsburg Apt!    8569221
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# 19990          Greg           Manhattan   Upper West Side  40.80173
# 19991         Hadar            Brooklyn          Flatbush  40.65335
# 19992        Taylor              Queens  Long Island City  40.76006
# 19993      Royalton           Manhattan  Theater District  40.75491
# 19994          Adam            Brooklyn          Flatbush  40.64314
# 19995       Adriana            Brooklyn   Windsor Terrace  40.65360
# 19996         Sarah           Manhattan   Upper West Side  40.80188
# 19997         Kaveh           Manhattan   Upper East Side  40.78110
# 19998  Carol Gloria               Bronx      Clason Point  40.81225
# 19999          Andi            Brooklyn      Williamsburg  40.71829
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 19990  -73.96625     Private room     70               1                  0
# 19991  -73.96257  Entire home/apt    120               3                 13
# 19992  -73.94080     Private room     55               4                  2
# 19993  -73.98507     Private room    100               1                  3
# 19994  -73.95705  Entire home/apt     75               3                 10
# 19995  -73.97546  Entire home/apt    143              14                  2
# 19996  -73.96808  Entire home/apt    200               2                 22
# 19997  -73.94567  Entire home/apt    220               3                 28
# 19998  -73.85502     Private room     80               1                  4
# 19999  -73.95819     Private room    109               3                  3
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 19990         NaN                NaN                               1
# 19991  2016-08-27               0.28                               2
# 19992  2019-06-01               0.65                               5
# 19993  2019-06-16               3.00                               9
# 19994  2019-01-03               0.84                               1
# 19995  2016-08-27               0.04                               1
# 19996  2019-05-21               0.50                               1
# 19997  2019-05-23               0.50                               1
# 19998  2019-07-01               1.48                               7
# 19999  2019-04-28               1.07                               2
#
#        availability_365
# 19990                 0
# 19991               327
# 19992                89
# 19993               318
# 19994                 0
# 19995                10
# 19996                 0
# 19997               293
# 19998               365
# 19999                97
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">northern-sky-6</strong> at: <a href='https://wandb.ai/nguyenhuy39/nyc_airbnb/runs/9bcgdsmy' target="_blank">https://wandb.ai/nguyenhuy39/nyc_airbnb/runs/9bcgdsmy</a><br/> View job at <a href='https://wandb.ai/nguyenhuy39/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE3ODkzMDgzNg==/version_details/v0' target="_blank">https://wandb.ai/nguyenhuy39/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE3ODkzMDgzNg==/version_details/v0</a><br/>Synced 7 W&B file(s), 0 media file(s), 11 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240525_143329-9bcgdsmy/logs</code>
